# %%
import pandas as pd

# %%
dataku = pd.read_csv('kapal_titanic.csv')

# %%
dataku
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
data_age_1 = dataku['age']
data_age_fare_1 = dataku[['age','fare']]
data_age_fare_2 = dataku[list(('age','fare'))]

print(data_age_1)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
print(type(dataku))
print(type(data_age_1))
print(type(data_age_fare_1))
print(type(data_age_fare_2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data_age_2 = dataku[['age']]

print(type(data_age_2))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data_age_2
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
dataku['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
dataku.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
dataku.age.equals(dataku['age'])
# Out:
# True

# %% [markdown]
# # ILOC
#
# ## .iloc[baris, kolom]

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
dataku.iloc[0]
# Out:
# survived       0
# pclass         3
# sex         male
# age         22.0
# sibsp          1
# parch          0
# fare        7.25
# embarked       S
# deck         NaN
# Name: 0, dtype: object

# %%
dataku.iloc[:10:3]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
dataku.iloc[:,0:3]
# Out:
#      survived  pclass     sex
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
# [891 rows x 3 columns]

# %%
dataku.iloc[-5:-2, -9:]
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN

# %%
dataku.iloc[[0,2,4]]
# Out:
#    survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 0         0       3    male  22.0      1      0  7.250        S  NaN
# 2         1       3  female  26.0      0      0  7.925        S  NaN
# 4         0       3    male  35.0      0      0  8.050        S  NaN

# %%
dataku.iloc[[0,2,4],[1,3,6]]
# Out:
#    pclass   age   fare
# 0       3  22.0  7.250
# 2       3  26.0  7.925
# 4       3  35.0  8.050

# %%
dataku.iloc[:,[1,3,5]]
# Out:
#      pclass   age  parch
# 0         3  22.0      0
# 1         1  38.0      0
# 2         3  26.0      0
# 3         1  35.0      0
# 4         3  35.0      0
# ..      ...   ...    ...
# 886       2  27.0      0
# 887       1  19.0      0
# 888       3   NaN      2
# 889       1  26.0      0
# 890       3  32.0      0
#
# [891 rows x 3 columns]

# %% [markdown]
# # Loc
#
# ## .loc['namabaris', 'namakolom']

# %%
newdataku = pd.read_csv('kapal_titanic.csv', index_col='embarked')

# %%
newdataku
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare deck
# embarked
# S                0       3    male  22.0      1      0   7.2500  NaN
# C                1       1  female  38.0      1      0  71.2833    C
# S                1       3  female  26.0      0      0   7.9250  NaN
# S                1       1  female  35.0      1      0  53.1000    C
# S                0       3    male  35.0      0      0   8.0500  NaN
# ...            ...     ...     ...   ...    ...    ...      ...  ...
# S                0       2    male  27.0      0      0  13.0000  NaN
# S                1       1  female  19.0      0      0  30.0000    B
# S                0       3  female   NaN      1      2  23.4500  NaN
# C                1       1    male  26.0      0      0  30.0000    C
# Q                0       3    male  32.0      0      0   7.7500  NaN
#
# [891 rows x 8 columns]

# %%
newdataku.loc['S']
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare deck
# embarked
# S                0       3    male  22.0      1      0   7.2500  NaN
# S                1       3  female  26.0      0      0   7.9250  NaN
# S                1       1  female  35.0      1      0  53.1000    C
# S                0       3    male  35.0      0      0   8.0500  NaN
# S                0       1    male  54.0      0      0  51.8625    E
# ...            ...     ...     ...   ...    ...    ...      ...  ...
# S                0       2    male  28.0      0      0  10.5000  NaN
# S                0       3    male  25.0      0      0   7.0500  NaN
# S                0       2    male  27.0      0      0  13.0000  NaN
# S                1       1  female  19.0      0      0  30.0000    B
# S                0       3  female   NaN      1      2  23.4500  NaN
#
# [644 rows x 8 columns]

# %%
newdataku.loc['S','age']
# Out:
# embarked
# S    22.0
# S    26.0
# S    35.0
# S    35.0
# S    54.0
#      ...
# S    28.0
# S    25.0
# S    27.0
# S    19.0
# S     NaN
# Name: age, Length: 644, dtype: float64

# %%
newdataku.loc['S',['age', 'fare']]
# Out:
#            age     fare
# embarked
# S         22.0   7.2500
# S         26.0   7.9250
# S         35.0  53.1000
# S         35.0   8.0500
# S         54.0  51.8625
# ...        ...      ...
# S         28.0  10.5000
# S         25.0   7.0500
# S         27.0  13.0000
# S         19.0  30.0000
# S          NaN  23.4500
#
# [644 rows x 2 columns]

# %%
newdataku.loc[['Q','C'], ['age', 'fare']]
# Out:
#            age     fare
# embarked
# Q          NaN   8.4583
# Q          2.0  29.1250
# Q         15.0   8.0292
# Q          NaN   7.8792
# Q          NaN   7.7500
# ...        ...      ...
# C         27.0  13.8583
# C         28.0  24.0000
# C         15.0   7.2250
# C         56.0  83.1583
# C         26.0  30.0000
#
# [245 rows x 2 columns]
